# %% [markdown]
# <a href="https://colab.research.google.com/github/mbilal-OU/python_workshop/blob/main/learning_project_number_guesser_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NUMBER GUESSER

# %%
import random
# print(random.randrange(start,stop))
r= random.randrange(-5,11)
print(r)
# Out:
# 7

# %%
import random
# print(random.randrange(start,stop))
r= random.randint(-5,11)  #includes last number
print(r)

# %%
import random
top_of_range =input("type a number:")
if top_of_range.isdigit():
    top_of_range = int(top_of_range)
    if top_of_range <= 0:
        print("please type a number larger than 0 next time")
        quit()
else:
    print("please type a number next time")
    quit()

random_number = random.randint(0,top_of_range)
print(random_number)
# Out:
# type a number:0
# please type a number larger than 0 next time
# 0
