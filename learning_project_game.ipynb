# %% [markdown]
# <a href="https://colab.research.google.com/github/mbilal-OU/python_workshop/blob/main/learning_project_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUIZ GAME

# %%
print("welcome to my computer quiz!")
# Out:
# welcome to my computer quiz!

# %%
playing=input("Do you want to play ? ")
#OR
# playing=input("Do you want to play ? ") .lower()
#if playing.upper() != "YES":
if playing.lower() != "yes":
  quit()

print("okay! lets play :)")

score= 0
# Out:
# Do you want to play ? yes
# okay! lets play :)

# %%
answer =input("what does CPU stands for ? ")
if answer == "central processing unit":
  print("correct!")
  score += 1
else:
  print("incorrect")
# Out:
# what does CPU stands for ? central processing unit
# correct!

# %%
answer =input("what does GPU stands for ? ")
if answer == "graphics processing unit":
  print("correct!")
  score += 1
else:
  print("incorrect")
# Out:
# what does GPU stands for ? graphics processing unit
# correct!

# %%
answer =input("what does RAM stands for ? ")
if answer.lower()== "random access memory":
  print("correct!")
  score += 1
else:
  print("incorrect")
# Out:
# what does RAM stands for ? random access memory
# correct!

# %%
answer =input("what does PSU stands for ? ") .lower()
if answer == "power supply":
  print("correct!")
  score += 1
else:
  print("incorrect")
# Out:
# what does PSU stands for ? power supply
# incorrect

# %%
print( "you got " + str(score) + " questions correct!")
print( "you got " + str((score/4)*100) + "%.")
# Out:
# you got 3 questions correct!
# you got 75.0%.
